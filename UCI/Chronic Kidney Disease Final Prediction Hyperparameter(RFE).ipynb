# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import time

# %%
df=pd.read_csv("F:\Work\diease detection\chronic-1.csv")

# %%
df=df.replace('?',np.nan)

# %%
data=df[['sg', 'al', 'su', 'bgr', 'sc', 'hemo', 'pcv', 'rbcc', 'rbc', 'htn',
       'dm', 'appet','Label']].copy()

# %%
#df1=df.drop(columns=['id','age','bp','sg','al','su','bgr','bu','sc','sod','pot','hemo','pcv','wbcc','rbcc'])

# %%
data
# Out:
#         sg   al   su  bgr    sc  hemo  pcv rbcc       rbc  htn   dm appet  \
# 0     1.02    1    0  121   1.2  15.4   44  5.2       NaN  yes  yes  good
# 1     1.02    4    0  NaN   0.8  11.3   38  NaN       NaN   no   no  good
# 2     1.02    0    0   92   1.2  14.9   48  5.4    normal   no   no  good
# 3     1.01    2    3  423   1.8   9.6   31  NaN    normal   no  yes  poor
# 4    1.005    4    0  117   3.8  11.2   32  3.9    normal  yes   no  poor
# ..     ...  ...  ...  ...   ...   ...  ...  ...       ...  ...  ...   ...
# 395   1.02    0    0   91   0.7    14   46  5.8    normal   no   no  good
# 396  1.015    3    2  463   2.8  12.2   40  4.6       NaN  yes  yes  good
# 397    NaN  NaN  NaN  103   5.3   6.3   19  2.6       NaN  yes   no  poor
# 398  1.015    3    0  106  15.2   8.6   26  2.5  abnormal  yes   no  good
# 399   1.02    0    0  119   0.7   NaN  NaN  NaN    normal   no   no  good
#
#       Label
# 0       ckd
# 1       ckd
# 2    notckd
# 3       ckd
# 4       ckd
# ..      ...
# 395  notckd
# 396     ckd
# 397     ckd
# 398     ckd
# 399  notckd
#
# [400 rows x 13 columns]

# %%
df1=data.drop(columns=['rbc','htn','dm','appet','Label'])

# %%
df1
# Out:
#         sg   al   su  bgr    sc  hemo  pcv rbcc
# 0     1.02    1    0  121   1.2  15.4   44  5.2
# 1     1.02    4    0  NaN   0.8  11.3   38  NaN
# 2     1.02    0    0   92   1.2  14.9   48  5.4
# 3     1.01    2    3  423   1.8   9.6   31  NaN
# 4    1.005    4    0  117   3.8  11.2   32  3.9
# ..     ...  ...  ...  ...   ...   ...  ...  ...
# 395   1.02    0    0   91   0.7    14   46  5.8
# 396  1.015    3    2  463   2.8  12.2   40  4.6
# 397    NaN  NaN  NaN  103   5.3   6.3   19  2.6
# 398  1.015    3    0  106  15.2   8.6   26  2.5
# 399   1.02    0    0  119   0.7   NaN  NaN  NaN
#
# [400 rows x 8 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %%
lr=LinearRegression()
imp=IterativeImputer(estimator=lr,verbose=2,max_iter=100, tol=1e-10, imputation_order='roman')

# %%
df2=imp.fit_transform(df1)
# Out:
# [IterativeImputer] Completing matrix with shape (400, 8)
# [IterativeImputer] Ending imputation round 1/100, elapsed time 0.04
# [IterativeImputer] Change: 182.27250463282854, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 2/100, elapsed time 0.08
# [IterativeImputer] Change: 18.887880713989645, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 3/100, elapsed time 0.11
# [IterativeImputer] Change: 15.664749386650769, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 4/100, elapsed time 0.13
# [IterativeImputer] Change: 12.960883525118291, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 5/100, elapsed time 0.15
# [IterativeImputer] Change: 10.635872032213825, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 6/100, elapsed time 0.16
# [IterativeImputer] Change: 8.77827989097402, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 7/100, elapsed time 0.18
# [IterativeImputer] Change: 7.293859443213448, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 8/100, elapsed time 0.20
# [IterativeImputer] Change: 6.09725716890984, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 9/100, elapsed time 0.23
# [IterativeImputer] Change: 5.122350285048179, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 10/100, elapsed time 0.25
# [IterativeImputer] Change: 4.320137985342714, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 11/100, elapsed time 0.27
# [IterativeImputer] Change: 3.654461657237922, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 12/100, elapsed time 0.29
# [IterativeImputer] Change: 3.0983620393446722, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 13/100, elapsed time 0.30
# [IterativeImputer] Change: 2.631387073162843, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 14/100, elapsed time 0.32
# [IterativeImputer] Change: 2.237712066310168, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 15/100, elapsed time 0.34
# [IterativeImputer] Change: 1.9048548285657159, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 16/100, elapsed time 0.36
# [IterativeImputer] Change: 1.6228000632393218, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 17/100, elapsed time 0.38
# [IterativeImputer] Change: 1.3833970089434293, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 18/100, elapsed time 0.40
# [IterativeImputer] Change: 1.1799374191622454, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 19/100, elapsed time 0.42
# [IterativeImputer] Change: 1.006852665645259, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 20/100, elapsed time 0.45
# [IterativeImputer] Change: 0.859490390055895, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 21/100, elapsed time 0.47
# [IterativeImputer] Change: 0.7339453023038887, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 22/100, elapsed time 0.49
# [IterativeImputer] Change: 0.6269277851050092, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 23/100, elapsed time 0.51
# [IterativeImputer] Change: 0.5356596790230401, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 24/100, elapsed time 0.52
# [IterativeImputer] Change: 0.4577902069535251, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 25/100, elapsed time 0.54
# [IterativeImputer] Change: 0.3913272512462993, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 26/100, elapsed time 0.56
# [IterativeImputer] Change: 0.33458062795642207, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 27/100, elapsed time 0.58
# [IterativeImputer] Change: 0.2861149280530715, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 28/100, elapsed time 0.60
# [IterativeImputer] Change: 0.24471010866443277, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 29/100, elapsed time 0.63
# [IterativeImputer] Change: 0.2093284368000483, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 30/100, elapsed time 0.64
# [IterativeImputer] Change: 0.17908668472848177, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 31/100, elapsed time 0.66
# [IterativeImputer] Change: 0.15323269379697368, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 32/100, elapsed time 0.68
# [IterativeImputer] Change: 0.13112558801173724, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 33/100, elapsed time 0.70
# [IterativeImputer] Change: 0.11221904669410665, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 34/100, elapsed time 0.71
# [IterativeImputer] Change: 0.09604714737792053, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 35/100, elapsed time 0.73
# [IterativeImputer] Change: 0.08221237199427289, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 36/100, elapsed time 0.75
# [IterativeImputer] Change: 0.07037543677885805, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 37/100, elapsed time 0.77
# [IterativeImputer] Change: 0.060246661404643076, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 38/100, elapsed time 0.80
# [IterativeImputer] Change: 0.05157863884267555, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 39/100, elapsed time 0.83
# [IterativeImputer] Change: 0.044160005387876344, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 40/100, elapsed time 0.85
# [IterativeImputer] Change: 0.037810142219972365, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 41/100, elapsed time 0.86
# [IterativeImputer] Change: 0.03237466636343389, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 42/100, elapsed time 0.88
# [IterativeImputer] Change: 0.02772159118567563, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 43/100, elapsed time 0.90
# [IterativeImputer] Change: 0.023738055216847354, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 44/100, elapsed time 0.91
# [IterativeImputer] Change: 0.020327533796126618, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 45/100, elapsed time 0.93
# [IterativeImputer] Change: 0.017407461128182256, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 46/100, elapsed time 0.94
# [IterativeImputer] Change: 0.014907201496966449, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 47/100, elapsed time 0.95
# [IterativeImputer] Change: 0.012766317689693274, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 48/100, elapsed time 0.97
# [IterativeImputer] Change: 0.010933092544351153, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 49/100, elapsed time 0.99
# [IterativeImputer] Change: 0.009363266219630573, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 50/100, elapsed time 1.01
# [IterativeImputer] Change: 0.008018957393944648, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 51/100, elapsed time 1.03
# [IterativeImputer] Change: 0.006867741342746703, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 52/100, elapsed time 1.04
# [IterativeImputer] Change: 0.005881861901320562, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 53/100, elapsed time 1.06
# [IterativeImputer] Change: 0.005037557717429975, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 54/100, elapsed time 1.07
# [IterativeImputer] Change: 0.004314486102355852, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 55/100, elapsed time 1.09
# [IterativeImputer] Change: 0.003695230263715432, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 56/100, elapsed time 1.11
# [IterativeImputer] Change: 0.0031648777779924586, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 57/100, elapsed time 1.13
# [IterativeImputer] Change: 0.0027106599710911006, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 58/100, elapsed time 1.14
# [IterativeImputer] Change: 0.0023216433251220803, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 59/100, elapsed time 1.15
# [IterativeImputer] Change: 0.0019884654236514976, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 60/100, elapsed time 1.18
# [IterativeImputer] Change: 0.0017031089680825673, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 61/100, elapsed time 1.20
# [IterativeImputer] Change: 0.0014587083263073453, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 62/100, elapsed time 1.24
# [IterativeImputer] Change: 0.001249383982828256, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 63/100, elapsed time 1.25
# [IterativeImputer] Change: 0.0010701007897864212, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 64/100, elapsed time 1.27
# [IterativeImputer] Change: 0.0009165466337814898, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 65/100, elapsed time 1.29
# [IterativeImputer] Change: 0.0007850285416637348, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 66/100, elapsed time 1.31
# [IterativeImputer] Change: 0.0006723837501489971, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 67/100, elapsed time 1.33
# [IterativeImputer] Change: 0.0005759035460228823, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 68/100, elapsed time 1.34
# [IterativeImputer] Change: 0.0004932680460778549, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 69/100, elapsed time 1.37
# [IterativeImputer] Change: 0.00042249037461350447, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 70/100, elapsed time 1.38
# [IterativeImputer] Change: 0.00036186884295719146, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 71/100, elapsed time 1.39
# [IterativeImputer] Change: 0.00030994599941336354, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 72/100, elapsed time 1.41
# [IterativeImputer] Change: 0.0002654735740545977, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 73/100, elapsed time 1.42
# [IterativeImputer] Change: 0.00022738243901110344, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 74/100, elapsed time 1.43
# [IterativeImputer] Change: 0.00019475690659631617, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 75/100, elapsed time 1.45
# [IterativeImputer] Change: 0.00016681269280671707, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 76/100, elapsed time 1.47
# [IterativeImputer] Change: 0.00014287806906465583, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 77/100, elapsed time 1.48
# [IterativeImputer] Change: 0.00012237769451539648, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 78/100, elapsed time 1.50
# [IterativeImputer] Change: 0.00010481879261492466, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 79/100, elapsed time 1.51
# [IterativeImputer] Change: 8.977929795106476e-05, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 80/100, elapsed time 1.53
# [IterativeImputer] Change: 7.689770865959566e-05, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 81/100, elapsed time 1.55
# [IterativeImputer] Change: 6.586439769362684e-05, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 82/100, elapsed time 1.57
# [IterativeImputer] Change: 5.641416404111865e-05, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 83/100, elapsed time 1.59
# [IterativeImputer] Change: 4.831986160902524e-05, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 84/100, elapsed time 1.60
# [IterativeImputer] Change: 4.138693923994019e-05, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 85/100, elapsed time 1.62
# [IterativeImputer] Change: 3.544875467631492e-05, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 86/100, elapsed time 1.63
# [IterativeImputer] Change: 3.0362583869125714e-05, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 87/100, elapsed time 1.64
# [IterativeImputer] Change: 2.600617865344823e-05, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 88/100, elapsed time 1.65
# [IterativeImputer] Change: 2.2274828690660442e-05, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 89/100, elapsed time 1.67
# [IterativeImputer] Change: 1.907885224938788e-05, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 90/100, elapsed time 1.68
# [IterativeImputer] Change: 1.6341434564637325e-05, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 91/100, elapsed time 1.69
# [IterativeImputer] Change: 1.3996777578961783e-05, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 92/100, elapsed time 1.71
# [IterativeImputer] Change: 1.1988533284101877e-05, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 93/100, elapsed time 1.73
# [IterativeImputer] Change: 1.026842897400293e-05, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 94/100, elapsed time 1.75
# [IterativeImputer] Change: 8.795125884253352e-06, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 95/100, elapsed time 1.77
# [IterativeImputer] Change: 7.533207885712656e-06, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 96/100, elapsed time 1.79
# [IterativeImputer] Change: 6.452351917651811e-06, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 97/100, elapsed time 1.80
# [IterativeImputer] Change: 5.526573901626364e-06, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 98/100, elapsed time 1.82
# [IterativeImputer] Change: 4.7336265291964e-06, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 99/100, elapsed time 1.83
# [IterativeImputer] Change: 4.054452859447721e-06, scaled tolerance: 4.9e-08
# [IterativeImputer] Ending imputation round 100/100, elapsed time 1.85
# [IterativeImputer] Change: 3.472722034825182e-06, scaled tolerance: 4.9e-08
# C:\Users\Md.Mustafizur Rahman\anaconda3\lib\site-packages\sklearn\impute\_iterative.py:685: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn("[IterativeImputer] Early stopping criterion not"

# %%
dl1=pd.DataFrame(df2,columns=('sg','al','su','bgr','sc','hemo','pcv','rbcc'))

# %%
dl1.head(20)
# Out:
#        sg   al   su         bgr    sc  hemo   pcv      rbcc
# 0   1.020  1.0  0.0  121.000000   1.2  15.4  44.0  5.200000
# 1   1.020  4.0  0.0  155.893755   0.8  11.3  38.0  4.483714
# 2   1.020  0.0  0.0   92.000000   1.2  14.9  48.0  5.400000
# 3   1.010  2.0  3.0  423.000000   1.8   9.6  31.0  3.742738
# 4   1.005  4.0  0.0  117.000000   3.8  11.2  32.0  3.900000
# 5   1.020  0.0  0.0   89.000000   0.5  16.7  52.0  5.000000
# 6   1.010  2.0  0.0  106.000000   1.4  11.6  35.0  4.600000
# 7   1.015  3.0  0.0   74.000000   1.1  12.2  39.0  4.400000
# 8   1.025  0.0  0.0  124.000000   1.0  14.9  41.0  5.700000
# 9   1.020  0.0  0.0  110.000000   0.7  14.3  40.0  5.800000
# 10  1.020  0.0  0.0  122.000000   0.8  17.1  41.0  5.200000
# 11  1.020  2.0  0.0   70.000000   7.2   9.5  29.0  3.700000
# 12  1.010  2.0  4.0  490.000000   4.0   9.4  28.0  3.561102
# 13  1.020  0.0  0.0  128.000000   1.2  15.2  52.0  5.700000
# 14  1.020  0.0  0.0  137.000000   0.5  13.6  44.0  4.500000
# 15  1.020  0.0  0.0  102.000000   0.7  13.2  44.0  5.400000
# 16  1.025  0.0  0.0  132.000000   1.1  13.7  45.0  5.600000
# 17  1.010  0.0  0.0  100.000000  24.0  12.4  36.0  4.152490
# 18  1.015  2.0  4.0  410.000000   1.1  12.4  44.0  5.000000
# 19  1.025  0.0  0.0   75.000000   0.8  16.8  51.0  6.500000

# %%
df3=data.drop(columns=['sg','al','su','bgr','sc','hemo','pcv','rbcc','Label'])

# %%
df3
# Out:
#           rbc  htn   dm appet
# 0         NaN  yes  yes  good
# 1         NaN   no   no  good
# 2      normal   no   no  good
# 3      normal   no  yes  poor
# 4      normal  yes   no  poor
# ..        ...  ...  ...   ...
# 395    normal   no   no  good
# 396       NaN  yes  yes  good
# 397       NaN  yes   no  poor
# 398  abnormal  yes   no  good
# 399    normal   no   no  good
#
# [400 rows x 4 columns]

# %%
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(strategy='constant',fill_value='Missing')
df4=imputer.fit_transform(df3)

# %%
dl2=pd.DataFrame(df4,columns=('rbc','htn','dm','appet'))

# %%
dl2.head()
# Out:
#        rbc  htn   dm appet
# 0  Missing  yes  yes  good
# 1  Missing   no   no  good
# 2   normal   no   no  good
# 3   normal   no  yes  poor
# 4   normal  yes   no  poor

# %%
from sklearn.preprocessing import OrdinalEncoder
ordi=OrdinalEncoder()

# %%
dl3=ordi.fit_transform(dl2)

# %%
dl4=pd.DataFrame(dl3,columns=('rbc','htn','dm','appet'))

# %%
dl4
# Out:
#      rbc  htn   dm  appet
# 0    0.0  2.0  2.0    1.0
# 1    0.0  1.0  1.0    1.0
# 2    2.0  1.0  1.0    1.0
# 3    2.0  1.0  2.0    3.0
# 4    2.0  2.0  1.0    3.0
# ..   ...  ...  ...    ...
# 395  2.0  1.0  1.0    1.0
# 396  0.0  2.0  2.0    1.0
# 397  0.0  2.0  1.0    3.0
# 398  1.0  2.0  1.0    1.0
# 399  2.0  1.0  1.0    1.0
#
# [400 rows x 4 columns]

# %%
x=pd.concat([dl1,dl4],axis=1)

# %%
x
# Out:
#            sg        al        su         bgr    sc      hemo        pcv  \
# 0    1.020000  1.000000  0.000000  121.000000   1.2  15.40000  44.000000
# 1    1.020000  4.000000  0.000000  155.893755   0.8  11.30000  38.000000
# 2    1.020000  0.000000  0.000000   92.000000   1.2  14.90000  48.000000
# 3    1.010000  2.000000  3.000000  423.000000   1.8   9.60000  31.000000
# 4    1.005000  4.000000  0.000000  117.000000   3.8  11.20000  32.000000
# ..        ...       ...       ...         ...   ...       ...        ...
# 395  1.020000  0.000000  0.000000   91.000000   0.7  14.00000  46.000000
# 396  1.015000  3.000000  2.000000  463.000000   2.8  12.20000  40.000000
# 397  1.010512  2.699747 -0.255426  103.000000   5.3   6.30000  19.000000
# 398  1.015000  3.000000  0.000000  106.000000  15.2   8.60000  26.000000
# 399  1.020000  0.000000  0.000000  119.000000   0.7  14.11269  43.142595
#
#          rbcc  rbc  htn   dm  appet
# 0    5.200000  0.0  2.0  2.0    1.0
# 1    4.483714  0.0  1.0  1.0    1.0
# 2    5.400000  2.0  1.0  1.0    1.0
# 3    3.742738  2.0  1.0  2.0    3.0
# 4    3.900000  2.0  2.0  1.0    3.0
# ..        ...  ...  ...  ...    ...
# 395  5.800000  2.0  1.0  1.0    1.0
# 396  4.600000  0.0  2.0  2.0    1.0
# 397  2.600000  0.0  2.0  1.0    3.0
# 398  2.500000  1.0  2.0  1.0    1.0
# 399  5.029438  2.0  1.0  1.0    1.0
#
# [400 rows x 12 columns]

# %%
y=df['Label']

# %%
a=pd.concat([x,y],axis=1)

# %%
a
# Out:
#            sg        al        su         bgr    sc      hemo        pcv  \
# 0    1.020000  1.000000  0.000000  121.000000   1.2  15.40000  44.000000
# 1    1.020000  4.000000  0.000000  155.893755   0.8  11.30000  38.000000
# 2    1.020000  0.000000  0.000000   92.000000   1.2  14.90000  48.000000
# 3    1.010000  2.000000  3.000000  423.000000   1.8   9.60000  31.000000
# 4    1.005000  4.000000  0.000000  117.000000   3.8  11.20000  32.000000
# ..        ...       ...       ...         ...   ...       ...        ...
# 395  1.020000  0.000000  0.000000   91.000000   0.7  14.00000  46.000000
# 396  1.015000  3.000000  2.000000  463.000000   2.8  12.20000  40.000000
# 397  1.010512  2.699747 -0.255426  103.000000   5.3   6.30000  19.000000
# 398  1.015000  3.000000  0.000000  106.000000  15.2   8.60000  26.000000
# 399  1.020000  0.000000  0.000000  119.000000   0.7  14.11269  43.142595
#
#          rbcc  rbc  htn   dm  appet   Label
# 0    5.200000  0.0  2.0  2.0    1.0     ckd
# 1    4.483714  0.0  1.0  1.0    1.0     ckd
# 2    5.400000  2.0  1.0  1.0    1.0  notckd
# 3    3.742738  2.0  1.0  2.0    3.0     ckd
# 4    3.900000  2.0  2.0  1.0    3.0     ckd
# ..        ...  ...  ...  ...    ...     ...
# 395  5.800000  2.0  1.0  1.0    1.0  notckd
# 396  4.600000  0.0  2.0  2.0    1.0     ckd
# 397  2.600000  0.0  2.0  1.0    3.0     ckd
# 398  2.500000  1.0  2.0  1.0    1.0     ckd
# 399  5.029438  2.0  1.0  1.0    1.0  notckd
#
# [400 rows x 13 columns]

# %%
#a=a.sort_values(['bu'],ascending=False)
#a.reset_index(drop=True,inplace=True)

# %%
#a.tail(40)

# %%
Label={'notckd':0,'ckd':1}
a['Label']=a['Label'].map(Label)

# %%
a.head(20)
# Out:
#        sg   al   su         bgr    sc  hemo   pcv      rbcc  rbc  htn   dm  \
# 0   1.020  1.0  0.0  121.000000   1.2  15.4  44.0  5.200000  0.0  2.0  2.0
# 1   1.020  4.0  0.0  155.893755   0.8  11.3  38.0  4.483714  0.0  1.0  1.0
# 2   1.020  0.0  0.0   92.000000   1.2  14.9  48.0  5.400000  2.0  1.0  1.0
# 3   1.010  2.0  3.0  423.000000   1.8   9.6  31.0  3.742738  2.0  1.0  2.0
# 4   1.005  4.0  0.0  117.000000   3.8  11.2  32.0  3.900000  2.0  2.0  1.0
# 5   1.020  0.0  0.0   89.000000   0.5  16.7  52.0  5.000000  2.0  1.0  1.0
# 6   1.010  2.0  0.0  106.000000   1.4  11.6  35.0  4.600000  2.0  1.0  1.0
# 7   1.015  3.0  0.0   74.000000   1.1  12.2  39.0  4.400000  0.0  2.0  2.0
# 8   1.025  0.0  0.0  124.000000   1.0  14.9  41.0  5.700000  2.0  1.0  1.0
# 9   1.020  0.0  0.0  110.000000   0.7  14.3  40.0  5.800000  2.0  1.0  1.0
# 10  1.020  0.0  0.0  122.000000   0.8  17.1  41.0  5.200000  2.0  1.0  1.0
# 11  1.020  2.0  0.0   70.000000   7.2   9.5  29.0  3.700000  1.0  2.0  2.0
# 12  1.010  2.0  4.0  490.000000   4.0   9.4  28.0  3.561102  0.0  2.0  2.0
# 13  1.020  0.0  0.0  128.000000   1.2  15.2  52.0  5.700000  2.0  1.0  1.0
# 14  1.020  0.0  0.0  137.000000   0.5  13.6  44.0  4.500000  2.0  1.0  1.0
# 15  1.020  0.0  0.0  102.000000   0.7  13.2  44.0  5.400000  2.0  1.0  1.0
# 16  1.025  0.0  0.0  132.000000   1.1  13.7  45.0  5.600000  2.0  1.0  1.0
# 17  1.010  0.0  0.0  100.000000  24.0  12.4  36.0  4.152490  0.0  1.0  1.0
# 18  1.015  2.0  4.0  410.000000   1.1  12.4  44.0  5.000000  2.0  1.0  2.0
# 19  1.025  0.0  0.0   75.000000   0.8  16.8  51.0  6.500000  2.0  1.0  1.0
#
#     appet  Label
# 0     1.0      1
# 1     1.0      1
# 2     1.0      0
# 3     3.0      1
# 4     3.0      1
# 5     1.0      0
# 6     1.0      1
# 7     1.0      1
# 8     1.0      0
# 9     0.0      0
# 10    1.0      0
# 11    3.0      1
# 12    1.0      1
# 13    1.0      0
# 14    1.0      0
# 15    1.0      0
# 16    1.0      0
# 17    1.0      1
# 18    1.0      1
# 19    1.0      0

# %%
u=a.iloc[:,:-1]
v=a['Label']

# %% [markdown]
# # SMOTE Technique

# %%
from imblearn.over_sampling import SMOTE
from imblearn.over_sampling import SVMSMOTE

# %%
smote=SMOTE()
sm = SVMSMOTE()

# %%
x_train_resample,y_train_resample=sm.fit_resample(u,v)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
k=scaler.fit_transform(x_train_resample)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(k,y_train_resample,test_size=0.2, random_state=0)

# %%
from sklearn.model_selection import ShuffleSplit
fold=ShuffleSplit(n_splits=5, test_size=0.1, random_state=0)
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RandomizedSearchCV

# %% [markdown]
# # Support Vector Machine

# %%
from sklearn.svm import SVC
svm=SVC()
param_grid={'C':[0.1,1,10,100],'gamma':['scale'],'kernel':['rbf']}
svm_randomgrid=RandomizedSearchCV(estimator=svm,param_distributions=param_grid,verbose=1,n_jobs=-1,cv=fold)
svm_randomgrid.fit(x_train,y_train)
svm_randomgrid.best_estimator_, svm_randomgrid.best_score_
# Out:
# C:\Users\Md.Mustafizur Rahman\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:285: UserWarning: The total space of parameters 4 is smaller than n_iter=10. Running 4 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# (SVC(C=0.1), 1.0)

# %% [markdown]
# # K-Nearest Neighbors

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
param_grid={'n_neighbors':range(1, 21, 2),
            'weights':['uniform', 'distance'],
            'metric':['euclidean', 'manhattan', 'minkowski']}
knn_randomgrid=RandomizedSearchCV(estimator=knn,param_distributions=param_grid,verbose=4,n_jobs=6,cv=fold)
knn_randomgrid.fit(x_train,y_train)
knn_randomgrid.best_params_, knn_randomgrid.best_score_
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# ({'weights': 'uniform', 'n_neighbors': 7, 'metric': 'minkowski'}, 1.0)

# %% [markdown]
# # Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier
gdb=GradientBoostingClassifier()
param_grid={'learning_rate':[0.01,0.05,0.1],
            'n_estimators':[100,200,300,400,500],
            'max_depth':[2,3,4,5,6,7,8],
            'min_samples_leaf':[4,8,10]}
gdb_randomgrid=RandomizedSearchCV(estimator=gdb,param_distributions=param_grid,verbose=1,n_jobs=-1,cv=fold)
gdb_randomgrid.fit(x_train,y_train)
gdb_randomgrid.best_params_, gdb_randomgrid.best_score_
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# ({'n_estimators': 500,
#   'min_samples_leaf': 8,
#   'max_depth': 3,
#   'learning_rate': 0.1},
#  1.0)

# %% [markdown]
# # LightGBM

# %%
from lightgbm import LGBMClassifier
lgb=LGBMClassifier()
param_grid={'learning_rate':[0.05,0.1],
            'n_estimators':[100,200,300,400,500],
            'max_depth':[2,3,4,5,6,7,8,9,10],
            'min_child_weight':[1,3,5,7,9]}
lgb_randomgrid=RandomizedSearchCV(estimator=lgb,param_distributions=param_grid,verbose=True,n_jobs=4,cv=fold)
lgb_randomgrid.fit(x_train,y_train)
lgb_randomgrid.best_params_, lgb_randomgrid.best_score_
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# ({'n_estimators': 200,
#   'min_child_weight': 1,
#   'max_depth': 7,
#   'learning_rate': 0.05},
#  0.9949999999999999)

# %% [markdown]
# # XgBoost

# %%
from xgboost import XGBClassifier
xgb=XGBClassifier()
param_grid={'learning_rate':[0.05,0.1,0.15,0.2,0.25],
            'n_estimators':[100,200,300,400,500,600,700],
            'max_depth':[2,3,4,5,6,7,8,9,10],
            'min_child_weight':[1,2,3,4,5,6,7,8,9],
            'eval_metric':['error']}
xgb_randomgrid=RandomizedSearchCV(estimator=xgb,param_distributions=param_grid,verbose=True,n_jobs=4,cv=fold)
xgb_randomgrid.fit(x_train,y_train)
xgb_randomgrid.best_params_, xgb_randomgrid.best_score_
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# C:\Users\Md.Mustafizur Rahman\anaconda3\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# ({'n_estimators': 700,
#   'min_child_weight': 1,
#   'max_depth': 4,
#   'learning_rate': 0.05,
#   'eval_metric': 'error'},
#  0.9949999999999999)
